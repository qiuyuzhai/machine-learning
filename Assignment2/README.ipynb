# %% [markdown]
# # Assignment 2 — Machine Learning Basics (简要说明)
#
# 简介
# 本目录包含用于练习反向传播与各种优化算法的 Jupyter Notebook：[Assignment2/Assignment2_25A .ipynb](Assignment2/Assignment2_25A .ipynb)。该笔记本实现了一个用 NumPy 编写的 MLP（含自定义激活）并对比了多种优化器（GD、SGD、Momentum、AdaGrad、ADAM 等）。
#
# 快速开始
# - 打开并运行：[Assignment2/Assignment2_25A .ipynb](Assignment2/Assignment2_25A .ipynb)。
# - 数据：用于测试的示例数据文件 [Assignment2/winequality-red.csv](Assignment2/winequality-red.csv)。
# - 建议按单元顺序运行，先完成 Section 1（实现反向传播 TODO），再运行 Section 2（优化器对比与可视化）。
#
# 主要模块 & 快速定位（Notebook 内符号）
# - MLP 与层实现：
#   - [`Base`](Assignment2/Assignment2_25A .ipynb)
#   - [`Hidden`](Assignment2/Assignment2_25A .ipynb)
#   - [`Hidden_Vondrick`](Assignment2/Assignment2_25A .ipynb)
#   - [`Output`](Assignment2/Assignment2_25A .ipynb)
#   - [`Loss`](Assignment2/Assignment2_25A .ipynb)
#   - [`NN`](Assignment2/Assignment2_25A .ipynb)
# - 优化器与更新规则（实现/实验）：
#   - [`gradient_descent`](Assignment2/Assignment2_25A .ipynb)
#   - [`stochastic_gradient_descent`](Assignment2/Assignment2_25A .ipynb)
#   - [`momentum`](Assignment2/Assignment2_25A .ipynb)
#   - [`adagrad`](Assignment2/Assignment2_25A .ipynb)
#   - [`adam`](Assignment2/Assignment2_25A .ipynb)
#   - 控制/可视化类：[`Optimizer`](Assignment2/Assignment2_25A .ipynb), [`plot_function`](Assignment2/Assignment2_25A .ipynb), [`plot_func`](Assignment2/Assignment2_25A .ipynb)
# - 测试函数（用于可视化优化路径）：
#   - [`bowl`](Assignment2/Assignment2_25A .ipynb)
#   - [`mult`](Assignment2/Assignment2_25A .ipynb)
#   - [`monkey`](Assignment2/Assignment2_25A .ipynb)
#   - [`matyas`](Assignment2/Assignment2_25A .ipynb)
#   - [`easom`](Assignment2/Assignment2_25A .ipynb)
#
# 要点提示
# - Section 1 要实现的 TODO 会影响网络学习（反向传播的 dW / db / 激活导数 等）。参考 notebook 中注释逐项实现并测试在红酒数据集（[Assignment2/winequality-red.csv](Assignment2/winequality-red.csv)）上的表现。
# - Section 2 通过可视化（plot_function）比较不同优化器在各种测试函数上的轨迹，调节超参数观察差异（学习率、动量系数等）。
# - 为复现和调试，建议固定随机种子并逐步检查中间量（shape 与数值范围）。
#
# 参考
# - 打开并阅读完整 Notebook 获取代码、说明与练习单元：[Assignment2/Assignment2_25A .ipynb](Assignment2/Assignment2_25A .ipynb)
